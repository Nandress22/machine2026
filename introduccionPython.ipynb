# %% [markdown]
# # Introduccion a Python
# <img src="img/image.jpg"/><br>
# **Nombre:** *Antonio*<br>
# **Fecha:** *07/01/2026*

# %%
#Comentario de Python
print("Esto es Python")
# Out:
# Esto es Python
